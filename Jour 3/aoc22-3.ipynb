# %%
#part 1
from string import ascii_letters #importation de ascii_letters pour faciliter

with open("input3a.txt") as file:
data = [i for i in file.read().strip().split("\n")]
    
    somme=0
    
    #interraction avec les donées
    for rucksack in data:
        moitier=len(rucksack)//2 #trouver la moitier
        
        gauche = set(rucksack[:moitier]) #permet de voir les carractères unique a gauche
        droite = set(rucksack[moitier:]) #permet de voir les caractères unique a droite
        
        for prio, char in enumerate(ascii_letters): #trouver les prioritées
            if char in gauche and char in droite:
                somme += prio + 1
                
    print(somme)
# Out:
# 8123

# %%
#part 2
from string import ascii_letters #importation de ascii_letters pour faciliter

with open("input3a.txt") as file:
    data = [i for i in file.read().strip().split("\n")]
    
    somme=0
    
    #interraction avec les donées
    for rucksack in data:
        moitier=len(rucksack)//2 #trouver la moitier
        
        gauche = set(rucksack[:moitier]) #permet de voir les carractères unique a gauche
        droite = set(rucksack[moitier:]) #permet de voir les caractères unique a droite
        
        for prio, char in enumerate(ascii_letters): #trouver les prioritées
            if char in gauche and char in droite:
                somme += prio + 1
    # ajout pour part 2
    j=3
    somme = 0
    for i in range(0,len(data), 3): 
        rucksack = data[i:j] #i commence a zéro puis 3 a la boucle suivante / j a 3 puis 6 etc
        j += 3
        
        for prio, char in enumerate(ascii_letters): # trouve la réponse
             if char in rucksack[0] and char in rucksack[1] and char in rucksack[2]: # pour les 3
                    somme += prio + 1
    print(somme)
# Out:
# 2620
